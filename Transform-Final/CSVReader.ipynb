# %%
# SQL giving errors when uploading original version. Read / write CSV in Pandas to physically select encoding type

import pandas as pd

# %%
# Name of the CSV file
file = 'ISO_db.csv'

df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df
# Out:
#        0                                        ISO 3166[1]  \
# 0      1                                    Country name[9]
# 1      2                                        Afghanistan
# 2      5                                            Albania
# 3      6                                            Algeria
# 4      7                                     American Samoa
# 5      8                                            Andorra
# 6      9                                             Angola
# 7     10                                           Anguilla
# 8     11                                         Antarctica
# 9     12                                Antigua and Barbuda
# 10    13                                          Argentina
# 11    14                                            Armenia
# 12    15                                              Aruba
# 13    17                                          Australia
# 14    18                                            Austria
# ...

# %%
df.to_csv('ISO_Clean.csv', encoding="ISO-8859-1")
