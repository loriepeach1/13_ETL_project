# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
import pymongo
import pandas as pd
from splinter import Browser

# %%
#############################################################
#  Use pandas to see how clean the table can be imported
#############################################################

# %%
url = 'https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes'

# %%
tables = pd.read_html(url)
tables

# %%
#convert the table to a dataframe.   NOTE:   the [0] indicates the first table.  If there were more than one, remember to set the index.
countryISO_df = tables[0]
#marsFacts_df.columns = ['FactName', 'FactValue']
countryISO_df.head(20)
# Out:
#                                                   0  \
# 0                                       ISO 3166[1]
# 1                                   Country name[9]
# 2                                       Afghanistan
# 3   Akrotiri and Dhekelia – See United Kingdom, The
# 4                                     Åland Islands
# 5                                           Albania
# 6                                           Algeria
# 7                                    American Samoa
# 8                                           Andorra
# 9                                            Angola
# 10                                         Anguilla
# 11                                   Antarctica [a]
# 12                              Antigua and Barbuda
# 13                                        Argentina
# 14                                          Armenia
# 15                                            Aruba
# 16     Ashmore and Cartier Islands – See Australia.
# 17                                    Australia [b]
# 18                                          Austria
# 19                                       Azerbaijan
#
#                                                     1                     2  \
# 0                              Official state name[5]  Sovereignty[5][6][7]
# 1                                     Alpha-2 code[9]       Alpha-3 code[9]
# 2                 The Islamic Republic of Afghanistan       UN member state
# 3                                                 NaN                   NaN
# 4                                               Åland               Finland
# 5                             The Republic of Albania       UN member state
# 6         The People's Democratic Republic of Algeria       UN member state
# 7                     The Territory of American Samoa         United States
# 8                         The Principality of Andorra       UN member state
# 9                              The Republic of Angola       UN member state
# 10                                           Anguilla        United Kingdom
# 11  All land and ice shelves south of the 60th par...      Antarctic Treaty
# 12                                Antigua and Barbuda       UN member state
# 13                             The Argentine Republic       UN member state
# 14                            The Republic of Armenia       UN member state
# 15                                              Aruba           Netherlands
# 16                                                NaN                   NaN
# 17                      The Commonwealth of Australia       UN member state
# 18                            The Republic of Austria       UN member state
# 19                         The Republic of Azerbaijan       UN member state
#
#                                                     3  \
# 0                                       ISO 3166-1[2]
# 1                                     Numeric code[9]
# 2   .mw-parser-output .monospaced{font-family:mono...
# 3                                                 NaN
# 4                                                  AX
# 5                                                  AL
# 6                                                  DZ
# 7                                                  AS
# 8                                                  AD
# 9                                                  AO
# 10                                                 AI
# 11                                                 AQ
# 12                                                 AG
# 13                                                 AR
# 14                                                 AM
# 15                                                 AW
# 16                                                NaN
# 17                                                 AU
# 18                                                 AT
# 19                                                 AZ
#
#                             4                  5              6    7
# 0               ISO 3166-2[3]  Internet ccTLD[8]            NaN  NaN
# 1   Subdivision code links[3]                NaN            NaN  NaN
# 2                         AFG                004  ISO 3166-2:AF  .af
# 3                         NaN                NaN            NaN  NaN
# 4                         ALA                248  ISO 3166-2:AX  .ax
# 5                         ALB                008  ISO 3166-2:AL  .al
# 6                         DZA                012  ISO 3166-2:DZ  .dz
# 7                         ASM                016  ISO 3166-2:AS  .as
# 8                         AND                020  ISO 3166-2:AD  .ad
# 9                         AGO                024  ISO 3166-2:AO  .ao
# 10                        AIA                660  ISO 3166-2:AI  .ai
# 11                        ATA                010  ISO 3166-2:AQ  .aq
# 12                        ATG                028  ISO 3166-2:AG  .ag
# 13                        ARG                032  ISO 3166-2:AR  .ar
# 14                        ARM                051  ISO 3166-2:AM  .am
# 15                        ABW                533  ISO 3166-2:AW  .aw
# 16                        NaN                NaN            NaN  NaN
# 17                        AUS                036  ISO 3166-2:AU  .au
# 18                        AUT                040  ISO 3166-2:AT  .at
# 19                        AZE                031  ISO 3166-2:AZ  .az

# %%
#############################################################
#  Use Web scraping
#############################################################

# %%
#ensure Chrome Driver is in the same directory as this notebook.   (Different for MAC user)
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

#navigate to the site which will be scraped
url = 'https://www.nationsonline.org/oneworld/country_code_list.htm'
browser.visit(url)

# %%
# Retrieve page with the requests module
response = requests.get(url)

# Create BeautifulSoup object of this URL with the featured image; parse with 'html.parser'
soup = bs(response.text, 'html.parser')

# %%
print(soup.prettify())

# %%
country2 = soup.find('td',{'class': "abs"}).text

print(country2)
# Out:
# A

# %%
#create another beautiful soup object with only the table details
country = soup.find_all('td',{"class": "abs"}
print(country)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-9e518ec8230e> in <module>
#       1 #create another beautiful soup object with only the table details
# ----> 2 country = soup.find_all('td',{"class": "abs"}.text())
#       3 print(country)
#
# AttributeError: 'dict' object has no attribute 'text'
